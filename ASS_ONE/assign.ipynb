# %%
# !pip install html5lib

# %%
import pandas as pd

url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv"
df = pd.read_csv(url)
print(len(df))
# Out:
# 9943

# %%
df
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 0     2026-01-29T16:06:33.320Z  33.297667 -116.447667    4.10  0.85      ml
# 1     2026-01-29T16:00:15.381Z  63.217000 -150.646000  133.10  1.80      ml
# 2     2026-01-29T15:45:47.980Z  33.471667 -116.368667    5.70  0.60      ml
# 3     2026-01-29T15:43:21.030Z  36.988667 -121.649170    1.83  1.00      md
# 4     2026-01-29T15:43:18.539Z  63.007000 -148.632000   62.40  2.00      ml
# ...                        ...        ...         ...     ...   ...     ...
# 9938  2025-12-30T16:38:58.540Z  37.961333 -122.054833   13.41  0.93      md
# 9939  2025-12-30T16:38:25.940Z  33.353500 -116.263500   11.51  1.60      ml
# 9940  2025-12-30T16:38:12.099Z  35.799667  -95.028500    2.51  2.09      ml
# 9941  2025-12-30T16:28:38.694Z  60.402000 -139.574900    5.00  2.70      ml
# 9942  2025-12-30T16:17:17.430Z  40.355333 -125.015000    6.12  2.41      md
#
# ...

# %%
df.to_csv('index.csv')
