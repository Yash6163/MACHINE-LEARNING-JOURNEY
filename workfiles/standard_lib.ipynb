# %%
import os
print(os.getcwd())
# Out:
# /Users/yashkumar/Desktop/ai ml code/workfiles

# %%
##high level operations on files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 ##high level operations on files
#       2 import shutil
# ----> 3 shutil.copyfile('source.txt','destination.txt')
#
# File ~/Desktop/ai ml code/venv/lib/python3.12/shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
#     262             with open(dst, 'wb') as fdst:
#     263                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source.txt'

# %%
import json 
data=[1,2,3,4]
json_str=json.dumps(data)
print(json_str)
print(json_str[0])
parsed_data=json.loads(json_str)
print(parsed_data)
print(parsed_data[0])
# Out:
# [1, 2, 3, 4]
# [
# [1, 2, 3, 4]
# 1

# %%
import csv
with open('example.csv',mode='w',newline='')as file:
    writer=csv.writer(file)
    writer.writerow(['Name','age'])
    writer.writerow(['yash',18])
with open('example.csv',mode='r')as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'age']
# ['yash', '18']

# %%
from datetime import datetime , timedelta 
now=datetime.now()
print(now)
yesterday=now-timedelta(days=2)
print(yesterday)
# Out:
# 2025-06-01 17:11:45.943547
# 2025-05-30 17:11:45.943547

# %%
import time
print(time.time())
time.sleep(5)
print(time.time())
# Out:
# 1748778194.3226938
# 1748778199.328473

# %%
import re
pattern=r'\d+'
test='there are 123 apples'
match=re.search(pattern,test)
print(match.group())
# Out:
# 123
