# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /Users/yashkumar/Desktop/ai ml code/.venv/lib/python3.12/site-packages (6.0.0)

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /Users/yashkumar/Desktop/ai ml code/.venv/lib/python3.12/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /Users/yashkumar/Desktop/ai ml code/.venv/lib/python3.12/site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in /Users/yashkumar/Desktop/ai ml code/.venv/lib/python3.12/site-packages (from html5lib) (0.5.1)

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/yashkumar/Desktop/ai ml code/.venv/lib/python3.12/site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/yashkumar/Desktop/ai ml code/.venv/lib/python3.12/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/yashkumar/Desktop/ai ml code/.venv/lib/python3.12/site-packages (from beautifulsoup4) (4.14.0)

# %%
import ssl
print(ssl.get_default_verify_paths())
# Out:
# DefaultVerifyPaths(cafile='/Library/Frameworks/Python.framework/Versions/3.12/etc/openssl/cert.pem', capath=None, openssl_cafile_env='SSL_CERT_FILE', openssl_cafile='/Library/Frameworks/Python.framework/Versions/3.12/etc/openssl/cert.pem', openssl_capath_env='SSL_CERT_DIR', openssl_capath='/Library/Frameworks/Python.framework/Versions/3.12/etc/openssl/certs')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://www.worldometers.info/gdp/gdp-by-country/"
response = requests.get(url)  # disables SSL check

soup = BeautifulSoup(response.text, 'lxml')

tables = pd.read_html(str(soup))
print(tables[0])

sns.lineplot(x="Country",y="GDP (nominal, 2023)",data="tables[0]")
plt.show()
# Out:
#        #           Country  GDP (nominal, 2023)     GDP (abbrev.) GDP Growth  \
# 0      1     United States  $27,720,700,000,000  $27.721 trillion      2.89%
# 1      2             China  $17,794,800,000,000  $17.795 trillion      5.25%
# 2      3           Germany   $4,525,700,000,000   $4.526 trillion     −0.27%
# 3      4             Japan   $4,204,490,000,000   $4.204 trillion      1.68%
# 4      5             India   $3,567,550,000,000   $3.568 trillion      8.15%
# ..   ...               ...                  ...               ...        ...
# 176  177        Micronesia         $460,000,000      $460 million      0.78%
# 177  178             Palau         $281,849,063  $281.849 million      1.88%
# 178  179          Kiribati         $279,208,903  $279.209 million      4.12%
# 179  180  Marshall Islands         $259,300,000    $259.3 million     −3.93%
# 180  181            Tuvalu          $62,280,312    $62.28 million      3.85%
#
#      Population (2023) GDP per capita Share of World GDP
# 0            343477335        $80,706             26.11%
# 1           1422584933        $12,509             16.76%
# 2             84548231        $53,528              4.26%
# 3            124370947        $33,806              3.96%
# 4           1438069596         $2,481              3.36%
# ..                 ...            ...                ...
# 176             112630         $4,084           0.00043%
# 177              17727        $15,899           0.00027%
# 178             132530         $2,107           0.00026%
# 179              38827         $6,678           0.00024%
# 180               9816         $6,345          0.000059%
#
# [181 rows x 8 columns]
# /var/folders/cl/f_fmb9gx3tlb36p11rypnlyw0000gn/T/ipykernel_11890/1441579560.py:12: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(str(soup))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 15
#      12 tables = pd.read_html(str(soup))
#      13 print(tables[0])
# ---> 15 sns.lineplot(x="Country",y="GDP (nominal, 2023)",data="tables[0]")
#      16 plt.show()
#
# File ~/Desktop/ai ml code/.venv/lib/python3.12/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)    481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/Desktop/ai ml code/.venv/lib/python3.12/site-packages/seaborn/relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)    210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File ~/Desktop/ai ml code/.venv/lib/python3.12/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/Desktop/ai ml code/.venv/lib/python3.12/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/Desktop/ai ml code/.venv/lib/python3.12/site-packages/seaborn/_core/data.py:57, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
# ---> 57     data = handle_data_source(data)
#      58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#
# File ~/Desktop/ai ml code/.venv/lib/python3.12/site-packages/seaborn/_core/data.py:278, in handle_data_source(data)
#     276 elif data is not None and not isinstance(data, Mapping):
#     277     err = f"Data source must be a DataFrame or Mapping, not {type(data)!r}."
# --> 278     raise TypeError(err)
#     280 return data
#
# TypeError: Data source must be a DataFrame or Mapping, not <class 'str'>.
