# %%
def outer(func):
    def inner():
        print("line 1 is out ")
        func()
        print("line 2 is out")
    return inner
@outer   #decorator is here
def find():
    print("hello")
find()
# Out:
# line 1 is out
# hello
# line 2 is out
