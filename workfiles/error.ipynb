# %%
##exception try ,except block
try:
    a=b
except:
    print("variable has not been assigned")
# Out:
# variable has not been assigned

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result=1/2
    a=b
except Exception as zz:
    print(zz)
    print("hey please enter denominator greater than zero")
# Out:
# name 'b' is not defined
# hey please enter denominator greater than zero

# %%
try :
    z=int(input("enter the number  : "))
    result=10/z
except ValueError :
    print("not a valid number ")
except ZeroDivisionError :
    print("enter the denominator greater than zero")
except Exception as ex :
    print(ex)
# Out:
# enter the denominator greater than zero

# %%
##try except and else block
try :
    num=int(input("enter the number : "))
    result=10/num
except ValueError :
    print("this is not a valid number")
except ZeroDivisionError:
    print("you can't divide by zero")
else :
    print(int(result))
# Out:
# 5

# %%
##try , except  , else and finally
try :
    num=int(input("enter the number : "))
    result=10/num
except ValueError :
    print("this is not a valid number")
except ZeroDivisionError:
    print("you can't divide by zero")
else :
    print(int(result))
finally :
    print('exceution complete')
# Out:
# this is not a valid number
# exceution complete

# %%
try :
    file=open('example1.txt','r')
    content=file.read()
    print(content)
except FileNotFoundError :
    print("the file does not exists")
except Exception as ex :
    print(ex)
finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print('file closed')
# Out:
# the file does not exists
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 11
#       9     print(ex)
#      10 finally:
# ---> 11     if 'file' in locals() or not file.closed():
#      12         file.close()
#      13         print('file closed')
#
# NameError: name 'file' is not defined
