# %%
from sklearn.preprocessing import LabelEncoder
lbl_encoder=LabelEncoder()

# %%
import pandas as pd
df=pd.DataFrame({'color':['red','blue','green','green','red','blue']})
encc=lbl_encoder.fit_transform(df[['color']])

encc
# Out:
# /Users/yashkumar/Desktop/ai ml code/venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([2, 0, 1, 1, 2, 0])

# %%
enc=lbl_encoder.transform([['red']])
enc
# Out:
# /Users/yashkumar/Desktop/ai ml code/venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# array([2])

# %% [markdown]
# ###ORDINAL ENCODING

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc=OrdinalEncoder()
import pandas as pd
df=pd.DataFrame({'color':['red','blue','green','blue','green','red']})
enc=ord_enc.fit_transform(df[['color']])
print(enc)
# Out:
# [[2.]
#  [0.]
#  [1.]
#  [0.]
#  [1.]
#  [2.]]
